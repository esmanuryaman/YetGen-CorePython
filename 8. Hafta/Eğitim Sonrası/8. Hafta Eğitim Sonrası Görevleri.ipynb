# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
import time 

giris_sayisi = int(input("Kaç kere giriş yapacaksınız?"))

def bilgi_al():
    isim = input("isim soyisim: ")
    yas = int(input("yas: "))
    kilo = float(input("kilo (kg): "))
    boy = float(input("boy (m): "))
    return isim, yas, kilo, boy

def vki_hesapla(kilo, boy):
    return kilo / (boy**2)

def deger_hesapla(vki):
    if vki < 18.5:
        return  ("zayıf")
    elif vki<=24.9:
        return ("normal kilolu")
    elif vki<=29.9:
        return "fazla kilolu"
    elif vki<=39.9:
        return "obez"
    elif vki>40:
        return  ("ileri obez")

# HER FONKSİYONUN TEK BİR GÖREVİ OLUR. BUNA SINGULARITY PRENSIBI DENIR.
def output(isim, yas, kilo, boy, vki, deger, kayit_tarihi):
    t1 = f"kullanici adi {isim}"
    t2 = f"kullanıcının yas, kilo, boy bilgisi {yas},{kilo},{boy}"
    t3= f"kullanıcın vkisi {vki}"
    t4 = f"değer aralığı {deger}" 
    t5 = f"oluşturma tarihi: {kayit_tarihi}"
    return (t1 + "\n" + t2 +"\n" + t3 + "\n"+t4 +"\n"+ t5)

for i in range(giris_sayisi):
    print(f"kullanıcı kaydı {i+1}")
    # YetNot: isim değişkenini tanımlayarak kullanıcıdan isim  soyisim bilgisini alalım.
    isim, yas, kilo, boy = bilgi_al()
    vki = vki_hesapla(kilo, boy)
    deger = deger_hesapla(vki)
    kayit_tarihi = time.ctime(time.time())
    output_1 = output(isim, yas, kilo, boy, vki, deger, kayit_tarihi)
    with open("saglık.txt", "a") as f:
          f.write(output_1)
          f.write("*"*20)
          f.write("\n")
          print("kullanıcı kaydedildi.")
# Out:
# kullanıcı kaydı 1
# kullanıcı kaydedildi.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
import datetime

def menuGoruntule():
    menu = {
        "meyve": {
            "cilek": 3.0,
            "muz": 2.5,
            "elma": 2.0,
            "portakal": 2.5
        },
        "sut": {
            "sut": 1.0,
            "bademSutu": 1.5,
            "soyaSutu": 1.5
        },
        "tatlandirici": {
            "bal": 0.5,
            "seker": 0.3,
            "stevia": 0.4
        }
    }
    for kategori, urunler in menu.items():
        print(f"{kategori.capitalize()}:")
        for urun, fiyat in urunler.items():
            print(f"  {urun.capitalize()}: {fiyat} TL")
    return menu

def satinAl(menu):
    toplamFiyat = 0.0
    secimler = {}

    print("Smoothie oluşturmak için seçeneklerinizi girin:")

    for kategori in menu:
        print(f"{kategori.capitalize()} seçenekleri:")
        urun = input(f"Lütfen {kategori} seçin: ")
        while urun not in menu[kategori]:
            print(f"{urun} geçerli bir seçenek değil. Tekrar deneyin.")
            urun = input(f"Lütfen {kategori} seçin: ")
        secimler[kategori] = urun
        toplamFiyat += menu[kategori][urun]

    tarih = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    logMesaji = f"Tarih: {tarih}, Seçimler: {secimler}, Toplam Fiyat: {toplamFiyat} TL\n"

    logYaz(logMesaji)

    print(f"Smoothie oluşturuldu! Toplam Fiyat: {toplamFiyat} TL")
    return toplamFiyat

def logYaz(logMesaji):
    with open("smoothieLog.txt", "a") as logDosyasi:
        logDosyasi.write(logMesaji)

def anaProgram():
    while True:
        print("YetBar'a hoşgeldiniz!")
        print("1. Menüyü Görüntüle")
        print("2. Smoothie Satın Al")
        print("3. Çıkış")

        secim = input("Lütfen bir seçenek girin: ")

        if secim == "1":
            menu = menuGoruntule()
        elif secim == "2":
            menu = menuGoruntule()  # Menüyü her seferinde güncel tutmak için tekrar görüntüle
            satinAl(menu)
        elif secim == "3":
            print("Çıkış yapılıyor...")
            break
        else:
            print("Geçersiz seçenek. Lütfen tekrar deneyin.")

if __name__ == "__main__":
    anaProgram()
# Out:
# YetBar'a hoşgeldiniz!
# 1. Menüyü Görüntüle
# 2. Smoothie Satın Al
# 3. Çıkış
# Meyve:
#   Cilek: 3.0 TL
#   Muz: 2.5 TL
#   Elma: 2.0 TL
#   Portakal: 2.5 TL
# Sut:
#   Sut: 1.0 TL
#   Bademsutu: 1.5 TL
#   Soyasutu: 1.5 TL
# Tatlandirici:
#   Bal: 0.5 TL
#   Seker: 0.3 TL
#   Stevia: 0.4 TL
# YetBar'a hoşgeldiniz!
# 1. Menüyü Görüntüle
# 2. Smoothie Satın Al
# 3. Çıkış
# Meyve:
#   Cilek: 3.0 TL
#   Muz: 2.5 TL
#   Elma: 2.0 TL
#   Portakal: 2.5 TL
# Sut:
#   Sut: 1.0 TL
#   Bademsutu: 1.5 TL
#   Soyasutu: 1.5 TL
# Tatlandirici:
#   Bal: 0.5 TL
#   Seker: 0.3 TL
#   Stevia: 0.4 TL
# Smoothie oluşturmak için seçeneklerinizi girin:
# Meyve seçenekleri:
# Sut seçenekleri:
# Tatlandirici seçenekleri:
# Smoothie oluşturuldu! Toplam Fiyat: 4.5 TL
# YetBar'a hoşgeldiniz!
# 1. Menüyü Görüntüle
# 2. Smoothie Satın Al
# 3. Çıkış
# Çıkış yapılıyor...
